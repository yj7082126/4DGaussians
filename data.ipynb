# %%
import os, sys
os.environ["CUDA_VISIBLE_DEVICES"] = "4,"
from pathlib import Path
import json, shutil
from tqdm import tqdm
import numpy as np
np.set_printoptions(suppress=True)

import pandas as pd
from PIL import Image
from pyquaternion import Quaternion
import torch
import sqlite3
from database import COLMAPDatabase
from scene.colmap_loader import qvec2rotmat, rotmat2qvec
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
root_dir = Path("kubric4d/test/scn02902")
out_dir = Path("samples/scn02902_test2")

(out_dir / "images").mkdir(parents=True, exist_ok=True)
(out_dir / "colmap").mkdir(parents=True, exist_ok=True)
(out_dir / "colmap/images").mkdir(parents=True, exist_ok=True)
(out_dir / "colmap/sparse_custom").mkdir(parents=True, exist_ok=True)
(out_dir / "colmap/sparse/0").mkdir(parents=True, exist_ok=True)
(out_dir / "colmap/dense/workspace").mkdir(parents=True, exist_ok=True)

# %%
# cameras = sorted(list(root_dir.glob("*.json")), key=lambda x: int(x.stem.split("_v")[-1]))

# cam_path = cameras[0]
# name = cam_path.stem.replace(root_dir.stem, "frames")
# metadata = json.loads(cam_path.read_bytes())
# img_paths = sorted(list(root_dir.glob(f"{name}/rgba_*.png")))

# img_path = img_paths[0]
# t = 0

# qvec = np.array(metadata['camera']['quaternions'][t])
# T = np.array(metadata['camera']['positions'][t])

# c2w = np.eye(4, dtype=np.float32)
# c2w[0:3, 0:3] = qvec2rotmat(qvec)
# c2w[0:3, 3] = T
# c2w[0:3, 1] *= -1.0
# c2w[0:3, 2] *= -1.0
# w2c = np.linalg.inv(c2w)
# R, T = w2c[:3,:3], w2c[:3,3]
# qvec = rotmat2qvec(R)
# print(qvec)

# %%
object_images_txt = ""
object_cameras_txt = ""
idx = 0
cameras = sorted(list(root_dir.glob("*.json")), key=lambda x: int(x.stem.split("_v")[-1]))
cameras = [cameras[4]]
for cam_path in cameras:
    name = cam_path.stem.replace(root_dir.stem, "frames")
    metadata = json.loads(cam_path.read_bytes())
    W, H = metadata['scene']['resolution']

    K = np.abs(metadata['camera']['K'])
    K = torch.tensor(K, dtype=torch.float32)
    K[0, :] *= W
    K[1, :] *= H
    focal = K[0,0]
    # focal = 32.0
    princp = K[0,2], K[1,2]
    for img_path in sorted(list(root_dir.glob(f"{name}/rgba_*.png"))):
        new_img_name = f"{name}-{img_path.stem}.png"
        t = int(img_path.stem.split("_")[-1])
        if t % 4 == 0:
            shutil.copy(img_path, out_dir / f"images/{new_img_name}")
        # if t == 0:
            qvec = np.array(metadata['camera']['quaternions'][t])
            T = np.array(metadata['camera']['positions'][t])

            # R = qvec2rotmat(qvec)
            # R[:, 1] *= -1.0
            # R[:, 2] *= -1.0

            # R = -np.transpose(R)
            # R[:,0] *= -1.0
            # T = -T
            # T = -np.matmul(R,T)
            # qvec = rotmat2qvec(np.transpose(R))

            c2w = np.eye(4, dtype=np.float32)
            c2w[0:3, 0:3] = qvec2rotmat(qvec)
            c2w[0:3, 3] = T
            c2w[0:3, 1] *= -1.0
            c2w[0:3, 2] *= -1.0
            w2c = np.linalg.inv(c2w)
            R, T = w2c[:3,:3], w2c[:3,3]
            qvec = rotmat2qvec(R)

            shutil.copy(img_path, out_dir / f"colmap/images/{new_img_name}")
            object_images_txt += f"{idx+1} {' '.join([str(x) for x in qvec])} {' '.join([str(x) for x in T])} 1 {new_img_name}\n\n"
            object_cameras_txt += f"{idx+1} SIMPLE_PINHOLE {W} {H} {focal} {princp[0]} {princp[1]}\n"
            idx += 1

(out_dir / "colmap/sparse_custom/images.txt").write_text(object_images_txt)
(out_dir / "colmap/sparse_custom/cameras.txt").write_text(object_cameras_txt)
(out_dir / "colmap/sparse_custom/points3D.txt").write_text("")
# Out:
# 0

# %%
# !colmap feature_extractor --database_path $out_dir/colmap/database.db --image_path $out_dir/colmap/images \
 --SiftExtraction.max_image_size 4096 --SiftExtraction.max_num_features 16384 \
 --SiftExtraction.estimate_affine_shape 1 \
 --SiftExtraction.domain_size_pooling 1
# Out:
# I0115 21:18:40.194579 161324 misc.cc:44]
# ==============================================================================
# Feature extraction
# ==============================================================================
# I0115 21:18:40.259552 161421 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.260349 161422 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.260493 161423 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.261437 161425 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.261885 161426 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.267939 161433 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.263507 161428 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.264101 161424 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.264361 161429 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.265197 161430 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.266053 161431 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.266894 161432 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.269150 161436 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.269451 161434 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.269850 161435 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.269860 161437 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.262679 161427 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.271512 161441 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.272004 161442 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.272939 161444 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.273880 161446 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.274351 161447 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.275056 161438 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.275080 161443 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.278445 161445 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.278623 161456 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.279417 161458 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.279914 161459 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.282895 161455 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.283785 161460 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.275755 161450 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.276234 161451 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.276754 161448 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.277617 161452 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.277647 161454 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.277757 161439 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.277781 161453 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.277788 161440 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.277884 161449 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.284327 161461 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.284642 161462 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.284742 161463 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.286387 161464 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.286826 161465 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.287585 161466 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.288143 161467 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.288650 161468 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.289206 161469 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.289710 161470 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.290267 161471 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.290820 161472 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.291380 161473 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.292433 161475 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.292995 161476 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.293519 161477 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.294080 161478 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.294595 161474 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.297327 161481 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.294617 161479 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.295527 161480 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.298381 161483 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.298957 161484 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.299369 161485 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.308413 161482 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.308650 161486 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.309213 161487 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.309741 161488 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.310292 161489 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.310806 161490 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.311357 161491 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.311882 161492 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.312434 161493 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.312956 161494 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.313467 161495 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.313987 161496 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.314482 161497 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.315017 161498 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.315537 161499 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.316082 161500 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.316603 161501 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.317150 161502 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.317665 161503 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.318235 161504 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.318769 161505 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.319319 161506 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.319820 161507 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.320371 161508 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.320873 161509 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.321415 161510 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.321916 161511 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.322445 161512 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.323007 161513 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.323518 161514 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.324076 161515 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.324579 161516 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:40.325112 161517 sift.cc:717] Creating Covariant SIFT CPU feature extractor
# I0115 21:18:41.280169 161518 feature_extraction.cc:258] Processed file [1/15]
# I0115 21:18:41.283972 161518 feature_extraction.cc:261]   Name:            frames_p0_v4-rgba_00000.png
# I0115 21:18:41.283978 161518 feature_extraction.cc:270]   Dimensions:      576 x 384
# I0115 21:18:41.283984 161518 feature_extraction.cc:273]   Camera:          #1 - SIMPLE_RADIAL
# I0115 21:18:41.283990 161518 feature_extraction.cc:276]   Focal Length:    691.20px
# I0115 21:18:41.284003 161518 feature_extraction.cc:280]   Features:        1434
# I0115 21:18:41.302889 161518 feature_extraction.cc:258] Processed file [2/15]
# I0115 21:18:41.302906 161518 feature_extraction.cc:261]   Name:            frames_p0_v4-rgba_00008.png
# I0115 21:18:41.302914 161518 feature_extraction.cc:270]   Dimensions:      576 x 384
# I0115 21:18:41.302980 161518 feature_extraction.cc:273]   Camera:          #3 - SIMPLE_RADIAL
# I0115 21:18:41.302985 161518 feature_extraction.cc:276]   Focal Length:    691.20px
# I0115 21:18:41.302992 161518 feature_extraction.cc:280]   Features:        1458
# I0115 21:18:41.311618 161518 feature_extraction.cc:258] Processed file [3/15]
# I0115 21:18:41.311631 161518 feature_extraction.cc:261]   Name:            frames_p0_v4-rgba_00004.png
# I0115 21:18:41.311637 161518 feature_extraction.cc:270]   Dimensions:      576 x 384
# I0115 21:18:41.311645 161518 feature_extraction.cc:273]   Camera:          #2 - SIMPLE_RADIAL
# I0115 21:18:41.311650 161518 feature_extraction.cc:276]   Focal Length:    691.20px
# I0115 21:18:41.311657 161518 feature_extraction.cc:280]   Features:        1427
# I0115 21:18:41.333734 161518 feature_extraction.cc:258] Processed file [4/15]
# I0115 21:18:41.333743 161518 feature_extraction.cc:261]   Name:            frames_p0_v4-rgba_00012.png
# I0115 21:18:41.333747 161518 feature_extraction.cc:270]   Dimensions:      576 x 384
# I0115 21:18:41.333753 161518 feature_extraction.cc:273]   Camera:          #4 - SIMPLE_RADIAL
# I0115 21:18:41.333757 161518 feature_extraction.cc:276]   Focal Length:    691.20px
# I0115 21:18:41.333762 161518 feature_extraction.cc:280]   Features:        1441
# I0115 21:18:41.399910 161518 feature_extraction.cc:258] Processed file [5/15]
# I0115 21:18:41.399991 161518 feature_extraction.cc:261]   Name:            frames_p0_v4-rgba_00028.png
# I0115 21:18:41.399996 161518 feature_extraction.cc:270]   Dimensions:      576 x 384
# I0115 21:18:41.399999 161518 feature_extraction.cc:273]   Camera:          #8 - SIMPLE_RADIAL
# I0115 21:18:41.400003 161518 feature_extraction.cc:276]   Focal Length:    691.20px
# I0115 21:18:41.400010 161518 feature_extraction.cc:280]   Features:        1398
# I0115 21:18:41.409963 161518 feature_extraction.cc:258] Processed file [6/15]
# I0115 21:18:41.409972 161518 feature_extraction.cc:261]   Name:            frames_p0_v4-rgba_00020.png
# I0115 21:18:41.409976 161518 feature_extraction.cc:270]   Dimensions:      576 x 384
# I0115 21:18:41.409981 161518 feature_extraction.cc:273]   Camera:          #6 - SIMPLE_RADIAL
# I0115 21:18:41.409988 161518 feature_extraction.cc:276]   Focal Length:    691.20px
# I0115 21:18:41.409996 161518 feature_extraction.cc:280]   Features:        1437
# I0115 21:18:41.433230 161518 feature_extraction.cc:258] Processed file [7/15]
# I0115 21:18:41.433239 161518 feature_extraction.cc:261]   Name:            frames_p0_v4-rgba_00024.png
# I0115 21:18:41.433243 161518 feature_extraction.cc:270]   Dimensions:      576 x 384
# I0115 21:18:41.433248 161518 feature_extraction.cc:273]   Camera:          #7 - SIMPLE_RADIAL
# I0115 21:18:41.433254 161518 feature_extraction.cc:276]   Focal Length:    691.20px
# I0115 21:18:41.433261 161518 feature_extraction.cc:280]   Features:        1409
# I0115 21:18:41.438314 161518 feature_extraction.cc:258] Processed file [8/15]
# I0115 21:18:41.438323 161518 feature_extraction.cc:261]   Name:            frames_p0_v4-rgba_00040.png
# I0115 21:18:41.438326 161518 feature_extraction.cc:270]   Dimensions:      576 x 384
# I0115 21:18:41.438333 161518 feature_extraction.cc:273]   Camera:          #11 - SIMPLE_RADIAL
# I0115 21:18:41.438338 161518 feature_extraction.cc:276]   Focal Length:    691.20px
# I0115 21:18:41.438344 161518 feature_extraction.cc:280]   Features:        1421
# I0115 21:18:41.449424 161518 feature_extraction.cc:258] Processed file [9/15]
# I0115 21:18:41.449431 161518 feature_extraction.cc:261]   Name:            frames_p0_v4-rgba_00016.png
# I0115 21:18:41.449437 161518 feature_extraction.cc:270]   Dimensions:      576 x 384
# I0115 21:18:41.449443 161518 feature_extraction.cc:273]   Camera:          #5 - SIMPLE_RADIAL
# I0115 21:18:41.449450 161518 feature_extraction.cc:276]   Focal Length:    691.20px
# I0115 21:18:41.449456 161518 feature_extraction.cc:280]   Features:        1420
# I0115 21:18:41.461349 161518 feature_extraction.cc:258] Processed file [10/15]
# I0115 21:18:41.461360 161518 feature_extraction.cc:261]   Name:            frames_p0_v4-rgba_00032.png
# I0115 21:18:41.461365 161518 feature_extraction.cc:270]   Dimensions:      576 x 384
# I0115 21:18:41.467386 161518 feature_extraction.cc:273]   Camera:          #9 - SIMPLE_RADIAL
# I0115 21:18:41.467392 161518 feature_extraction.cc:276]   Focal Length:    691.20px
# I0115 21:18:41.467402 161518 feature_extraction.cc:280]   Features:        1409
# I0115 21:18:41.472419 161518 feature_extraction.cc:258] Processed file [11/15]
# I0115 21:18:41.472429 161518 feature_extraction.cc:261]   Name:            frames_p0_v4-rgba_00044.png
# I0115 21:18:41.472434 161518 feature_extraction.cc:270]   Dimensions:      576 x 384
# I0115 21:18:41.472440 161518 feature_extraction.cc:273]   Camera:          #12 - SIMPLE_RADIAL
# I0115 21:18:41.472445 161518 feature_extraction.cc:276]   Focal Length:    691.20px
# I0115 21:18:41.472452 161518 feature_extraction.cc:280]   Features:        1429
# I0115 21:18:41.475045 161518 feature_extraction.cc:258] Processed file [12/15]
# I0115 21:18:41.475054 161518 feature_extraction.cc:261]   Name:            frames_p0_v4-rgba_00048.png
# I0115 21:18:41.475062 161518 feature_extraction.cc:270]   Dimensions:      576 x 384
# I0115 21:18:41.475068 161518 feature_extraction.cc:273]   Camera:          #13 - SIMPLE_RADIAL
# I0115 21:18:41.475075 161518 feature_extraction.cc:276]   Focal Length:    691.20px
# I0115 21:18:41.475080 161518 feature_extraction.cc:280]   Features:        1418
# I0115 21:18:41.492089 161518 feature_extraction.cc:258] Processed file [13/15]
# I0115 21:18:41.492101 161518 feature_extraction.cc:261]   Name:            frames_p0_v4-rgba_00036.png
# I0115 21:18:41.492107 161518 feature_extraction.cc:270]   Dimensions:      576 x 384
# I0115 21:18:41.492112 161518 feature_extraction.cc:273]   Camera:          #10 - SIMPLE_RADIAL
# I0115 21:18:41.492117 161518 feature_extraction.cc:276]   Focal Length:    691.20px
# I0115 21:18:41.492126 161518 feature_extraction.cc:280]   Features:        1413
# I0115 21:18:41.504410 161518 feature_extraction.cc:258] Processed file [14/15]
# I0115 21:18:41.504419 161518 feature_extraction.cc:261]   Name:            frames_p0_v4-rgba_00056.png
# I0115 21:18:41.504423 161518 feature_extraction.cc:270]   Dimensions:      576 x 384
# I0115 21:18:41.504431 161518 feature_extraction.cc:273]   Camera:          #15 - SIMPLE_RADIAL
# I0115 21:18:41.504436 161518 feature_extraction.cc:276]   Focal Length:    691.20px
# I0115 21:18:41.504442 161518 feature_extraction.cc:280]   Features:        1442
# I0115 21:18:41.504813 161518 feature_extraction.cc:258] Processed file [15/15]
# I0115 21:18:41.504822 161518 feature_extraction.cc:261]   Name:            frames_p0_v4-rgba_00052.png
# I0115 21:18:41.504828 161518 feature_extraction.cc:270]   Dimensions:      576 x 384
# I0115 21:18:41.504835 161518 feature_extraction.cc:273]   Camera:          #14 - SIMPLE_RADIAL
# I0115 21:18:41.504841 161518 feature_extraction.cc:276]   Focal Length:    691.20px
# I0115 21:18:41.504849 161518 feature_extraction.cc:280]   Features:        1415
# I0115 21:18:41.505847 161324 timer.cc:91] Elapsed time: 0.022 [minutes]

# %%
camModelDict = {
    'SIMPLE_PINHOLE': 0, 'PINHOLE': 1, 'SIMPLE_RADIAL': 2, 'RADIAL': 3,
    'OPENCV': 4, 'FULL_OPENCV': 5, 'SIMPLE_RADIAL_FISHEYE': 6,
    'RADIAL_FISHEYE': 7, 'OPENCV_FISHEYE': 8, 'FOV': 9,
    'THIN_PRISM_FISHEYE': 10
}

db = COLMAPDatabase.connect(out_dir / "colmap/database.db")
# db = COLMAPDatabase.connect("data/kubric_car/colmap/kubric_car/database.db")

# res = db.execute("SELECT sql FROM sqlite_master WHERE tbl_name = 'cameras' AND type = 'table'")
# element = res.fetchone()[0].replace('(', '').replace(')', '')
# # print("\n".join([x.strip() for x in ' '.join(element.split('cameras')[1:]).strip().split(",   ")]))

# res = db.execute("SELECT * FROM cameras")
# all_els = res.fetchall()
# df = pd.DataFrame(all_els, columns=['camera_id', 'model', 'width', 'height', 'params', 'prior_focal_length'])
# df['params'] = df['params'].apply(lambda blob: np.fromstring(blob, dtype=np.float64).reshape((-1,)))

camera_lines = (out_dir / "colmap/sparse_custom/cameras.txt").read_text()
for line in camera_lines.strip().split("\n"):
    cameraId, cameraModel, width, height, focal, princpx, princpy = line.split(' ')
    cameraModel = camModelDict[cameraModel]
    params = np.array([focal, princpx, princpy]).astype(np.float64)
    camera_id = db.update_camera(cameraModel, int(float(width)), int(float(height)), params, int(cameraId))
db.commit()
# print(int(cameraId), cameraModel, int(float(width)), int(float(height)), params)

res = db.execute("SELECT * FROM cameras")
all_els = res.fetchall()
df = pd.DataFrame(all_els, columns=['camera_id', 'model', 'width', 'height', 'params', 'prior_focal_length'])
df['params'] = df['params'].apply(lambda blob: np.fromstring(blob, dtype=np.float64).reshape((-1,)))
df
# Out:
#     camera_id  model  width  height                 params  prior_focal_length
# 0           1      0    576     384  [576.0, 288.0, 192.0]                   1
# 1           2      0    576     384  [576.0, 288.0, 192.0]                   1
# 2           3      0    576     384  [576.0, 288.0, 192.0]                   1
# 3           4      0    576     384  [576.0, 288.0, 192.0]                   1
# 4           5      0    576     384  [576.0, 288.0, 192.0]                   1
# 5           6      0    576     384  [576.0, 288.0, 192.0]                   1
# 6           7      0    576     384  [576.0, 288.0, 192.0]                   1
# 7           8      0    576     384  [576.0, 288.0, 192.0]                   1
# 8           9      0    576     384  [576.0, 288.0, 192.0]                   1
# 9          10      0    576     384  [576.0, 288.0, 192.0]                   1
# 10         11      0    576     384  [576.0, 288.0, 192.0]                   1
# 11         12      0    576     384  [576.0, 288.0, 192.0]                   1
# 12         13      0    576     384  [576.0, 288.0, 192.0]                   1
# 13         14      0    576     384  [576.0, 288.0, 192.0]                   1
# 14         15      0    576     384  [576.0, 288.0, 192.0]                   1

# %%
# !colmap exhaustive_matcher --database_path $out_dir/colmap/database.db --SiftMatching.guided_matching=true
# !colmap point_triangulator \
 --database_path $out_dir/colmap/database.db \
 --image_path $out_dir/colmap/images \
 --input_path $out_dir/colmap/sparse_custom \
 --output_path $out_dir/colmap/sparse/0
# Out:
# I0115 21:18:42.372572 161521 misc.cc:44]
# ==============================================================================
# Feature matching
# ==============================================================================
# I0115 21:18:42.373462 161522 sift.cc:1426] Creating SIFT GPU feature matcher
# I0115 21:18:42.434458 161620 sift.cc:1426] Creating SIFT GPU feature matcher
# I0115 21:18:42.954293 161521 pairing.cc:168] Generating exhaustive image pairs...
# I0115 21:18:42.954331 161521 pairing.cc:201] Matching block [1/1, 1/1]
# I0115 21:18:43.129029 161521 feature_matching.cc:46] in 0.175s
# I0115 21:18:43.130620 161521 timer.cc:91] Elapsed time: 0.013 [minutes]
# I0115 21:18:43.601706 161621 misc.cc:44]
# ==============================================================================
# Loading model
# ==============================================================================
# I0115 21:18:43.603085 161621 incremental_pipeline.cc:237] Loading database
# I0115 21:18:43.603701 161621 database_cache.cc:66] Loading cameras...
# I0115 21:18:43.603734 161621 database_cache.cc:76]  15 in 0.000s
# I0115 21:18:43.603740 161621 database_cache.cc:84] Loading matches...
# I0115 21:18:43.605270 161621 database_cache.cc:89]  105 in 0.002s
# I0115 21:18:43.605278 161621 database_cache.cc:105] Loading images...
# I0115 21:18:43.606105 161621 database_cache.cc:153]  15 in 0.001s (connected 15)
# I0115 21:18:43.606114 161621 database_cache.cc:164] Loading pose priors...
# I0115 21:18:43.606168 161621 database_cache.cc:175]  0 in 0.000s
# I0115 21:18:43.606173 161621 database_cache.cc:184] Building correspondence graph...
# I0115 21:18:43.615146 161621 database_cache.cc:210]  in 0.009s (ignored 0)
# I0115 21:18:43.615186 161621 timer.cc:91] Elapsed time: 0.000 [minutes]
# I0115 21:18:43.619571 161621 incremental_pipeline.cc:565] Iterative triangulation
# I0115 21:18:43.619578 161621 incremental_pipeline.cc:570] Triangulating image #1 (0)
# I0115 21:18:43.619582 161621 incremental_pipeline.cc:573] => Image sees 0 / 1261 points
# I0115 21:18:43.800266 161621 incremental_pipeline.cc:570] Triangulating image #2 (1)
# I0115 21:18:43.800276 161621 incremental_pipeline.cc:573] => Image sees 0 / 1359 points
# I0115 21:18:43.994220 161621 incremental_pipeline.cc:570] Triangulating image #3 (2)
# I0115 21:18:43.994233 161621 incremental_pipeline.cc:573] => Image sees 0 / 1278 points
# I0115 21:18:44.176263 161621 incremental_pipeline.cc:570] Triangulating image #4 (3)
# I0115 21:18:44.176292 161621 incremental_pipeline.cc:573] => Image sees 0 / 1358 points
# I0115 21:18:44.370496 161621 incremental_pipeline.cc:570] Triangulating image #5 (4)
# I0115 21:18:44.370512 161621 incremental_pipeline.cc:573] => Image sees 0 / 1374 points
# I0115 21:18:44.574389 161621 incremental_pipeline.cc:570] Triangulating image #6 (5)
# I0115 21:18:44.574401 161621 incremental_pipeline.cc:573] => Image sees 0 / 1386 points
# I0115 21:18:44.774885 161621 incremental_pipeline.cc:570] Triangulating image #7 (6)
# I0115 21:18:44.774901 161621 incremental_pipeline.cc:573] => Image sees 0 / 1385 points
# I0115 21:18:44.979060 161621 incremental_pipeline.cc:570] Triangulating image #8 (7)
# I0115 21:18:44.979082 161621 incremental_pipeline.cc:573] => Image sees 0 / 1404 points
# I0115 21:18:45.193142 161621 incremental_pipeline.cc:570] Triangulating image #9 (8)
# I0115 21:18:45.193171 161621 incremental_pipeline.cc:573] => Image sees 0 / 1365 points
# I0115 21:18:45.391010 161621 incremental_pipeline.cc:570] Triangulating image #10 (9)
# I0115 21:18:45.391028 161621 incremental_pipeline.cc:573] => Image sees 0 / 1389 points
# I0115 21:18:45.596427 161621 incremental_pipeline.cc:570] Triangulating image #11 (10)
# I0115 21:18:45.596438 161621 incremental_pipeline.cc:573] => Image sees 0 / 1410 points
# I0115 21:18:45.802021 161621 incremental_pipeline.cc:570] Triangulating image #12 (11)
# I0115 21:18:45.802031 161621 incremental_pipeline.cc:573] => Image sees 0 / 1401 points
# I0115 21:18:46.007555 161621 incremental_pipeline.cc:570] Triangulating image #13 (12)
# I0115 21:18:46.007565 161621 incremental_pipeline.cc:573] => Image sees 0 / 1395 points
# I0115 21:18:46.213207 161621 incremental_pipeline.cc:570] Triangulating image #14 (13)
# I0115 21:18:46.213217 161621 incremental_pipeline.cc:573] => Image sees 0 / 1411 points
# I0115 21:18:46.418668 161621 incremental_pipeline.cc:570] Triangulating image #15 (14)
# I0115 21:18:46.418678 161621 incremental_pipeline.cc:573] => Image sees 0 / 1402 points
# I0115 21:18:46.624698 161621 incremental_pipeline.cc:582] Retriangulation and Global bundle adjustment
# I0115 21:18:46.624835 161621 incremental_pipeline.cc:591] Extracting colors

# %%
# !colmap image_undistorter --image_path $out_dir/colmap/images --input_path $out_dir/colmap/sparse/0 --output_path $out_dir/colmap/dense/workspace
# !colmap patch_match_stereo --workspace_path $out_dir/colmap/dense/workspace
# !colmap stereo_fusion --workspace_path $out_dir/colmap/dense/workspace --output_path $out_dir/colmap/dense/workspace/fused.ply
# !python scripts/downsample_point.py $out_dir/colmap/dense/workspace/fused.ply $out_dir/colmap/point3D_multipleview.ply
# Out:
# I0115 21:18:57.460438 161622 misc.cc:44]
# ==============================================================================
# Reading reconstruction
# ==============================================================================
# I0115 21:18:57.462610 161622 image.cc:347] => Reconstruction with 15 images and 0 points
# I0115 21:18:57.462630 161622 misc.cc:44]
# ==============================================================================
# Image undistortion
# ==============================================================================
# I0115 21:18:57.602885 161622 undistortion.cc:215] Undistorting image [1/15]
# I0115 21:18:57.602907 161634 undistortion.cc:257] Undistorted image found; copying to location: samples/scn02902_test2/colmap/dense/workspace/images/frames_p0_v4-rgba_00048.png
# I0115 21:18:57.602898 161631 undistortion.cc:257] Undistorted image found; copying to location: samples/scn02902_test2/colmap/dense/workspace/images/frames_p0_v4-rgba_00016.png
# I0115 21:18:57.602898 161625 undistortion.cc:257] Undistorted image found; copying to location: samples/scn02902_test2/colmap/dense/workspace/images/frames_p0_v4-rgba_00004.png
# I0115 21:18:57.602900 161623 undistortion.cc:257] Undistorted image found; copying to location: samples/scn02902_test2/colmap/dense/workspace/images/frames_p0_v4-rgba_00000.png
# I0115 21:18:57.602900 161626 undistortion.cc:257] Undistorted image found; copying to location: samples/scn02902_test2/colmap/dense/workspace/images/frames_p0_v4-rgba_00012.png
# I0115 21:18:57.602892 161630 undistortion.cc:257] Undistorted image found; copying to location: samples/scn02902_test2/colmap/dense/workspace/images/frames_p0_v4-rgba_00040.png
# I0115 21:18:57.602900 161629 undistortion.cc:257] Undistorted image found; copying to location: samples/scn02902_test2/colmap/dense/workspace/images/frames_p0_v4-rgba_00024.png
# I0115 21:18:57.602902 161628 undistortion.cc:257] Undistorted image found; copying to location: samples/scn02902_test2/colmap/dense/workspace/images/frames_p0_v4-rgba_00020.png
# I0115 21:18:57.602903 161633 undistortion.cc:257] Undistorted image found; copying to location: samples/scn02902_test2/colmap/dense/workspace/images/frames_p0_v4-rgba_00032.png
# I0115 21:18:57.602916 161635 undistortion.cc:257] Undistorted image found; copying to location: samples/scn02902_test2/colmap/dense/workspace/images/frames_p0_v4-rgba_00036.png
# I0115 21:18:57.602907 161636 undistortion.cc:257] Undistorted image found; copying to location: samples/scn02902_test2/colmap/dense/workspace/images/frames_p0_v4-rgba_00056.png
# I0115 21:18:57.602907 161624 undistortion.cc:257] Undistorted image found; copying to location: samples/scn02902_test2/colmap/dense/workspace/images/frames_p0_v4-rgba_00008.png
# I0115 21:18:57.602990 161632 undistortion.cc:257] Undistorted image found; copying to location: samples/scn02902_test2/colmap/dense/workspace/images/frames_p0_v4-rgba_00044.png
# I0115 21:18:57.602892 161627 undistortion.cc:257] Undistorted image found; copying to location: samples/scn02902_test2/colmap/dense/workspace/images/frames_p0_v4-rgba_00028.png
# I0115 21:18:57.602908 161637 undistortion.cc:257] Undistorted image found; copying to location: samples/scn02902_test2/colmap/dense/workspace/images/frames_p0_v4-rgba_00052.png
# I0115 21:18:57.611039 161622 undistortion.cc:215] Undistorting image [2/15]
# I0115 21:18:57.611438 161622 undistortion.cc:215] Undistorting image [3/15]
# I0115 21:18:57.611447 161622 undistortion.cc:215] Undistorting image [4/15]
# I0115 21:18:57.611454 161622 undistortion.cc:215] Undistorting image [5/15]
# I0115 21:18:57.611459 161622 undistortion.cc:215] Undistorting image [6/15]
# I0115 21:18:57.611465 161622 undistortion.cc:215] Undistorting image [7/15]
# I0115 21:18:57.611471 161622 undistortion.cc:215] Undistorting image [8/15]
# I0115 21:18:57.611477 161622 undistortion.cc:215] Undistorting image [9/15]
# I0115 21:18:57.611483 161622 undistortion.cc:215] Undistorting image [10/15]
# I0115 21:18:57.611579 161622 undistortion.cc:215] Undistorting image [11/15]
# I0115 21:18:57.611588 161622 undistortion.cc:215] Undistorting image [12/15]
# I0115 21:18:57.611595 161622 undistortion.cc:215] Undistorting image [13/15]
# I0115 21:18:57.611603 161622 undistortion.cc:215] Undistorting image [14/15]
# I0115 21:18:57.611608 161622 undistortion.cc:215] Undistorting image [15/15]
# I0115 21:18:57.611613 161622 undistortion.cc:225] Writing reconstruction...
# I0115 21:18:57.614260 161622 undistortion.cc:230] Writing configuration...
# I0115 21:18:57.614370 161622 undistortion.cc:234] Writing scripts...
# I0115 21:18:57.614466 161622 timer.cc:91] Elapsed time: 0.003 [minutes]
# I0115 21:18:57.940435 161719 patch_match.cc:234] Reading workspace...
# I0115 21:18:57.942623 161719 patch_match.cc:264] Reading configuration...
# W0115 21:18:57.950925 161719 patch_match.cc:386] Ignoring reference image frames_p0_v4-rgba_00000.png, because it has no source images.
# W0115 21:18:57.950934 161719 patch_match.cc:386] Ignoring reference image frames_p0_v4-rgba_00008.png, because it has no source images.
# W0115 21:18:57.950937 161719 patch_match.cc:386] Ignoring reference image frames_p0_v4-rgba_00004.png, because it has no source images.
# W0115 21:18:57.950942 161719 patch_match.cc:386] Ignoring reference image frames_p0_v4-rgba_00012.png, because it has no source images.
# W0115 21:18:57.950945 161719 patch_match.cc:386] Ignoring reference image frames_p0_v4-rgba_00028.png, because it has no source images.
# W0115 21:18:57.950948 161719 patch_match.cc:386] Ignoring reference image frames_p0_v4-rgba_00020.png, because it has no source images.
# W0115 21:18:57.950951 161719 patch_match.cc:386] Ignoring reference image frames_p0_v4-rgba_00024.png, because it has no source images.
# W0115 21:18:57.950955 161719 patch_match.cc:386] Ignoring reference image frames_p0_v4-rgba_00040.png, because it has no source images.
# W0115 21:18:57.950958 161719 patch_match.cc:386] Ignoring reference image frames_p0_v4-rgba_00016.png, because it has no source images.
# W0115 21:18:57.950963 161719 patch_match.cc:386] Ignoring reference image frames_p0_v4-rgba_00032.png, because it has no source images.
# W0115 21:18:57.950965 161719 patch_match.cc:386] Ignoring reference image frames_p0_v4-rgba_00044.png, because it has no source images.
# W0115 21:18:57.950968 161719 patch_match.cc:386] Ignoring reference image frames_p0_v4-rgba_00048.png, because it has no source images.
# W0115 21:18:57.950973 161719 patch_match.cc:386] Ignoring reference image frames_p0_v4-rgba_00036.png, because it has no source images.
# W0115 21:18:57.950975 161719 patch_match.cc:386] Ignoring reference image frames_p0_v4-rgba_00056.png, because it has no source images.
# W0115 21:18:57.950979 161719 patch_match.cc:386] Ignoring reference image frames_p0_v4-rgba_00052.png, because it has no source images.
# I0115 21:18:57.950982 161719 patch_match.cc:395] Configuration has 0 problems...
# I0115 21:18:58.514873 161719 timer.cc:91] Elapsed time: 0.010 [minutes]
# I0115 21:18:58.829090 161722 misc.cc:51]
# StereoFusion::Options
# ---------------------
# I0115 21:18:58.829160 161722 fusion.cc:90] mask_path:
# I0115 21:18:58.829164 161722 fusion.cc:91] max_image_size: -1
# I0115 21:18:58.829173 161722 fusion.cc:92] min_num_pixels: 5
# I0115 21:18:58.829176 161722 fusion.cc:93] max_num_pixels: 10000
# I0115 21:18:58.829180 161722 fusion.cc:94] max_traversal_depth: 100
# I0115 21:18:58.829185 161722 fusion.cc:95] max_reproj_error: 2
# I0115 21:18:58.829195 161722 fusion.cc:96] max_depth_error: 0.01
# I0115 21:18:58.829200 161722 fusion.cc:97] max_normal_error: 10
# I0115 21:18:58.829206 161722 fusion.cc:98] check_num_images: 50
# I0115 21:18:58.829212 161722 fusion.cc:99] use_cache: 0
# I0115 21:18:58.829217 161722 fusion.cc:100] cache_size: 32
# I0115 21:18:58.829223 161722 fusion.cc:103] bbox_min: -3.40282e+38 -3.40282e+38 -3.40282e+38
# I0115 21:18:58.829236 161722 fusion.cc:104] bbox_max: 3.40282e+38 3.40282e+38 3.40282e+38
# I0115 21:18:58.829246 161722 fusion.cc:154] Reading workspace...
# I0115 21:18:58.951964 161722 workspace.cc:98] Loading workspace data with 96 threads...
# W0115 21:18:58.952066 161722 workspace.cc:105] Ignoring image frames_p0_v4-rgba_00000.png, because input does not exist.
# W0115 21:18:58.952080 161722 workspace.cc:105] Ignoring image frames_p0_v4-rgba_00008.png, because input does not exist.
# W0115 21:18:58.952095 161722 workspace.cc:105] Ignoring image frames_p0_v4-rgba_00004.png, because input does not exist.
# W0115 21:18:58.952107 161722 workspace.cc:105] Ignoring image frames_p0_v4-rgba_00012.png, because input does not exist.
# W0115 21:18:58.952121 161722 workspace.cc:105] Ignoring image frames_p0_v4-rgba_00028.png, because input does not exist.
# W0115 21:18:58.952133 161722 workspace.cc:105] Ignoring image frames_p0_v4-rgba_00020.png, because input does not exist.
# W0115 21:18:58.952147 161722 workspace.cc:105] Ignoring image frames_p0_v4-rgba_00024.png, because input does not exist.
# W0115 21:18:58.952158 161722 workspace.cc:105] Ignoring image frames_p0_v4-rgba_00040.png, because input does not exist.
# W0115 21:18:58.952171 161722 workspace.cc:105] Ignoring image frames_p0_v4-rgba_00016.png, because input does not exist.
# W0115 21:18:58.952184 161722 workspace.cc:105] Ignoring image frames_p0_v4-rgba_00032.png, because input does not exist.
# W0115 21:18:58.952196 161722 workspace.cc:105] Ignoring image frames_p0_v4-rgba_00044.png, because input does not exist.
# W0115 21:18:58.952209 161722 workspace.cc:105] Ignoring image frames_p0_v4-rgba_00048.png, because input does not exist.
# W0115 21:18:58.952221 161722 workspace.cc:105] Ignoring image frames_p0_v4-rgba_00036.png, because input does not exist.
# W0115 21:18:58.952234 161722 workspace.cc:105] Ignoring image frames_p0_v4-rgba_00056.png, because input does not exist.
# W0115 21:18:58.952247 161722 workspace.cc:105] Ignoring image frames_p0_v4-rgba_00052.png, because input does not exist.
# I0115 21:18:58.952253 161722 timer.cc:91] Elapsed time: 0.000 [minutes]
# I0115 21:18:58.973290 161722 fusion.cc:189] Reading configuration...
# W0115 21:18:58.973364 161722 fusion.cc:219] Ignoring image frames_p0_v4-rgba_00000.png, because input does not exist.
# W0115 21:18:58.973376 161722 fusion.cc:219] Ignoring image frames_p0_v4-rgba_00008.png, because input does not exist.
# W0115 21:18:58.973387 161722 fusion.cc:219] Ignoring image frames_p0_v4-rgba_00004.png, because input does not exist.
# W0115 21:18:58.973398 161722 fusion.cc:219] Ignoring image frames_p0_v4-rgba_00012.png, because input does not exist.
# W0115 21:18:58.973409 161722 fusion.cc:219] Ignoring image frames_p0_v4-rgba_00028.png, because input does not exist.
# W0115 21:18:58.973419 161722 fusion.cc:219] Ignoring image frames_p0_v4-rgba_00020.png, because input does not exist.
# W0115 21:18:58.973430 161722 fusion.cc:219] Ignoring image frames_p0_v4-rgba_00024.png, because input does not exist.
# W0115 21:18:58.973440 161722 fusion.cc:219] Ignoring image frames_p0_v4-rgba_00040.png, because input does not exist.
# W0115 21:18:58.973451 161722 fusion.cc:219] Ignoring image frames_p0_v4-rgba_00016.png, because input does not exist.
# W0115 21:18:58.973461 161722 fusion.cc:219] Ignoring image frames_p0_v4-rgba_00032.png, because input does not exist.
# W0115 21:18:58.973474 161722 fusion.cc:219] Ignoring image frames_p0_v4-rgba_00044.png, because input does not exist.
# W0115 21:18:58.973484 161722 fusion.cc:219] Ignoring image frames_p0_v4-rgba_00048.png, because input does not exist.
# W0115 21:18:58.973495 161722 fusion.cc:219] Ignoring image frames_p0_v4-rgba_00036.png, because input does not exist.
# W0115 21:18:58.973505 161722 fusion.cc:219] Ignoring image frames_p0_v4-rgba_00056.png, because input does not exist.
# W0115 21:18:58.973515 161722 fusion.cc:219] Ignoring image frames_p0_v4-rgba_00052.png, because input does not exist.
# I0115 21:18:58.973521 161722 fusion.cc:257] Starting fusion with 96 threads
# I0115 21:18:59.025144 161722 fusion.cc:293] Fusing image [1/15] with index 0
# I0115 21:18:59.025199 161722 fusion.cc:320]  in 0.000s (0 points)
# W0115 21:18:59.025548 161722 fusion.cc:341] Could not fuse any points. This is likely caused by incorrect settings - filtering must be enabled for the last call to patch match stereo.
# I0115 21:18:59.027648 161722 fusion.cc:347] Number of fused points: 0
# I0115 21:18:59.027652 161722 timer.cc:91] Elapsed time: 0.003 [minutes]
# I0115 21:18:59.047474 161722 mvs.cc:203] Writing output: samples/scn02902_test2/colmap/dense/workspace/fused.ply
# [Open3D WARNING] Read PLY failed: number of vertex <= 0.
# Total points: 0
# [Open3D WARNING] Write PLY failed: point cloud has 0 points.

# %%
from scene.colmap_loader import read_extrinsics_text, read_intrinsics_text, qvec2rotmat, \
    read_extrinsics_binary, read_intrinsics_binary, read_points3D_binary, read_points3D_text

datadir = "samples/scn02902/colmap"

cameras_extrinsic_file = os.path.join(datadir, "sparse/0/images.bin")
cameras_intrinsic_file = os.path.join(datadir, "sparse/0/cameras.bin")
cam_extrinsics = read_extrinsics_binary(cameras_extrinsic_file)
cam_intrinsics = read_intrinsics_binary(cameras_intrinsic_file)
cam_folder=os.path.join(datadir, "../")

image_folder = os.path.join(cam_folder, "images")
image_range = list(range(0, 60, 4))

image_paths, image_poses, image_times = [], [], []
for idx, key in enumerate(cam_extrinsics):
    extr = cam_extrinsics[key]
    R = np.transpose(qvec2rotmat(extr.qvec))
    T = np.array(extr.tvec)
    image_path_0 = os.path.join(image_folder, extr.name)
    for time in image_range:
        image_path = os.path.join(
            os.path.dirname(image_path_0), 
            os.path.basename(image_path_0).replace(
                "rgba_00000.png", f"rgba_{time:05d}.png"
            )
        )
        print(image_path)
# Out:
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v10-rgba_00000.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v10-rgba_00004.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v10-rgba_00008.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v10-rgba_00012.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v10-rgba_00016.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v10-rgba_00020.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v10-rgba_00024.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v10-rgba_00028.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v10-rgba_00032.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v10-rgba_00036.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v10-rgba_00040.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v10-rgba_00044.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v10-rgba_00048.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v10-rgba_00052.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v10-rgba_00056.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v11-rgba_00000.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v11-rgba_00004.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v11-rgba_00008.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v11-rgba_00012.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v11-rgba_00016.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v11-rgba_00020.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v11-rgba_00024.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v11-rgba_00028.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v11-rgba_00032.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v11-rgba_00036.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v11-rgba_00040.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v11-rgba_00044.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v11-rgba_00048.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v11-rgba_00052.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v11-rgba_00056.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v12-rgba_00000.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v12-rgba_00004.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v12-rgba_00008.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v12-rgba_00012.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v12-rgba_00016.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v12-rgba_00020.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v12-rgba_00024.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v12-rgba_00028.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v12-rgba_00032.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v12-rgba_00036.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v12-rgba_00040.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v12-rgba_00044.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v12-rgba_00048.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v12-rgba_00052.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v12-rgba_00056.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v13-rgba_00000.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v13-rgba_00004.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v13-rgba_00008.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v13-rgba_00012.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v13-rgba_00016.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v13-rgba_00020.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v13-rgba_00024.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v13-rgba_00028.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v13-rgba_00032.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v13-rgba_00036.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v13-rgba_00040.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v13-rgba_00044.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v13-rgba_00048.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v13-rgba_00052.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v13-rgba_00056.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v7-rgba_00000.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v7-rgba_00004.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v7-rgba_00008.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v7-rgba_00012.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v7-rgba_00016.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v7-rgba_00020.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v7-rgba_00024.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v7-rgba_00028.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v7-rgba_00032.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v7-rgba_00036.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v7-rgba_00040.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v7-rgba_00044.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v7-rgba_00048.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v7-rgba_00052.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v7-rgba_00056.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v8-rgba_00000.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v8-rgba_00004.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v8-rgba_00008.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v8-rgba_00012.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v8-rgba_00016.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v8-rgba_00020.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v8-rgba_00024.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v8-rgba_00028.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v8-rgba_00032.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v8-rgba_00036.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v8-rgba_00040.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v8-rgba_00044.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v8-rgba_00048.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v8-rgba_00052.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v8-rgba_00056.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v9-rgba_00000.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v9-rgba_00004.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v9-rgba_00008.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v9-rgba_00012.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v9-rgba_00016.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v9-rgba_00020.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v9-rgba_00024.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v9-rgba_00028.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v9-rgba_00032.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v9-rgba_00036.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v9-rgba_00040.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v9-rgba_00044.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v9-rgba_00048.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v9-rgba_00052.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v9-rgba_00056.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v6-rgba_00000.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v6-rgba_00004.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v6-rgba_00008.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v6-rgba_00012.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v6-rgba_00016.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v6-rgba_00020.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v6-rgba_00024.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v6-rgba_00028.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v6-rgba_00032.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v6-rgba_00036.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v6-rgba_00040.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v6-rgba_00044.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v6-rgba_00048.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v6-rgba_00052.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v6-rgba_00056.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v14-rgba_00000.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v14-rgba_00004.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v14-rgba_00008.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v14-rgba_00012.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v14-rgba_00016.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v14-rgba_00020.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v14-rgba_00024.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v14-rgba_00028.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v14-rgba_00032.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v14-rgba_00036.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v14-rgba_00040.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v14-rgba_00044.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v14-rgba_00048.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v14-rgba_00052.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v14-rgba_00056.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v15-rgba_00000.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v15-rgba_00004.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v15-rgba_00008.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v15-rgba_00012.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v15-rgba_00016.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v15-rgba_00020.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v15-rgba_00024.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v15-rgba_00028.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v15-rgba_00032.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v15-rgba_00036.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v15-rgba_00040.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v15-rgba_00044.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v15-rgba_00048.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v15-rgba_00052.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v15-rgba_00056.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v5-rgba_00000.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v5-rgba_00004.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v5-rgba_00008.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v5-rgba_00012.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v5-rgba_00016.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v5-rgba_00020.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v5-rgba_00024.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v5-rgba_00028.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v5-rgba_00032.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v5-rgba_00036.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v5-rgba_00040.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v5-rgba_00044.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v5-rgba_00048.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v5-rgba_00052.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v5-rgba_00056.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v4-rgba_00000.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v4-rgba_00004.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v4-rgba_00008.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v4-rgba_00012.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v4-rgba_00016.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v4-rgba_00020.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v4-rgba_00024.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v4-rgba_00028.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v4-rgba_00032.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v4-rgba_00036.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v4-rgba_00040.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v4-rgba_00044.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v4-rgba_00048.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v4-rgba_00052.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v4-rgba_00056.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v3-rgba_00000.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v3-rgba_00004.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v3-rgba_00008.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v3-rgba_00012.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v3-rgba_00016.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v3-rgba_00020.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v3-rgba_00024.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v3-rgba_00028.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v3-rgba_00032.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v3-rgba_00036.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v3-rgba_00040.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v3-rgba_00044.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v3-rgba_00048.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v3-rgba_00052.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v3-rgba_00056.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v0-rgba_00000.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v0-rgba_00004.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v0-rgba_00008.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v0-rgba_00012.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v0-rgba_00016.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v0-rgba_00020.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v0-rgba_00024.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v0-rgba_00028.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v0-rgba_00032.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v0-rgba_00036.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v0-rgba_00040.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v0-rgba_00044.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v0-rgba_00048.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v0-rgba_00052.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v0-rgba_00056.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v1-rgba_00000.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v1-rgba_00004.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v1-rgba_00008.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v1-rgba_00012.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v1-rgba_00016.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v1-rgba_00020.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v1-rgba_00024.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v1-rgba_00028.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v1-rgba_00032.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v1-rgba_00036.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v1-rgba_00040.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v1-rgba_00044.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v1-rgba_00048.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v1-rgba_00052.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v1-rgba_00056.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v2-rgba_00000.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v2-rgba_00004.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v2-rgba_00008.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v2-rgba_00012.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v2-rgba_00016.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v2-rgba_00020.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v2-rgba_00024.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v2-rgba_00028.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v2-rgba_00032.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v2-rgba_00036.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v2-rgba_00040.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v2-rgba_00044.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v2-rgba_00048.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v2-rgba_00052.png
# /data/3D_dataset/MVS/4DGaussians/samples/scn02902/colmap/../images/frames_p0_v2-rgba_00056.png

# %% [markdown]
# # ORIGIN

# %%
root_dir = Path("data/espresso")
(root_dir / "colmap").mkdir(parents=True, exist_ok=True)
(root_dir / "colmap/images").mkdir(parents=True, exist_ok=True)
(root_dir / "colmap/sparse_custom").mkdir(parents=True, exist_ok=True)
(root_dir / "colmap/sparse/0").mkdir(parents=True, exist_ok=True)
(root_dir / "colmap/dense/workspace").mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ### hypernerf2colmap

# %%
def rotmat2qvec(R):
    Rxx, Ryx, Rzx, Rxy, Ryy, Rzy, Rxz, Ryz, Rzz = R.flat
    K = np.array([
        [Rxx - Ryy - Rzz, 0, 0, 0],
        [Ryx + Rxy, Ryy - Rxx - Rzz, 0, 0],
        [Rzx + Rxz, Rzy + Ryz, Rzz - Rxx - Ryy, 0],
        [Ryz - Rzy, Rzx - Rxz, Rxy - Ryx, Rxx + Ryy + Rzz]]) / 3.0
    eigvals, eigvecs = np.linalg.eigh(K)
    qvec = eigvecs[[3, 0, 1, 2], np.argmax(eigvals)]
    if qvec[0] < 0:
        qvec *= -1
    return qvec
    
images = sorted(list((root_dir / "rgb/2x").glob("*.png")))
cameras = sorted(list((root_dir / "camera").glob("*.json")))
cams = [json.loads(x.read_bytes()) for x in cameras]
sizes = (len(cams) // 200) + 1

object_images_txt = ""
object_cameras_txt = ""
for cnt, (cam, image) in enumerate(zip(cams, images)):
    if (cnt+1) % sizes == 0:
        idx = cnt // sizes
        R = np.array(cam['orientation']).T
        T = -np.array(cam['position']) @ R 
        qvec = rotmat2qvec(R.T)
        object_images_txt += f"{idx+1} {' '.join([str(x) for x in qvec])} {' '.join([str(x) for x in T])} 1 {image.name}\n\n"

        img_size = cam['image_size'][0]/2, cam['image_size'][1]/2
        focal = cam['focal_length']/2
        princp = cam['principal_point'][0]/2, cam['principal_point'][1]/2
        object_cameras_txt += f"{idx+1} SIMPLE_PINHOLE {img_size[0]} {img_size[1]} {focal} {princp[0]} {princp[1]}\n"

        shutil.copy(image, root_dir / f"colmap/images/{image.name}")

(root_dir / "colmap/sparse_custom/images.txt").write_text(object_images_txt)
(root_dir / "colmap/sparse_custom/cameras.txt").write_text(object_cameras_txt)
(root_dir / "colmap/sparse_custom/points3D.txt").write_text("")

# %%
# !colmap feature_extractor --database_path $root_dir/colmap/database.db --image_path $root_dir/colmap/images \
 --SiftExtraction.max_image_size 4096 --SiftExtraction.max_num_features 16384 --SiftExtraction.estimate_affine_shape 1 \
 --SiftExtraction.domain_size_pooling 1

# %% [markdown]
# ### database

# %%
camModelDict = {
    'SIMPLE_PINHOLE': 0, 'PINHOLE': 1, 'SIMPLE_RADIAL': 2, 'RADIAL': 3,
    'OPENCV': 4, 'FULL_OPENCV': 5, 'SIMPLE_RADIAL_FISHEYE': 6,
    'RADIAL_FISHEYE': 7, 'OPENCV_FISHEYE': 8, 'FOV': 9,
    'THIN_PRISM_FISHEYE': 10
}

class COLMAPDatabase(sqlite3.Connection):
    @staticmethod
    def connect(database_path):
        return sqlite3.connect(database_path, factory=COLMAPDatabase)

    def __init__(self, *args, **kwargs):
        super(COLMAPDatabase, self).__init__(*args, **kwargs)

        self.create_tables = lambda: self.executescript(CREATE_ALL)
        self.create_cameras_table = lambda: self.executescript(CREATE_CAMERAS_TABLE)
        self.create_descriptors_table = lambda: self.executescript(CREATE_DESCRIPTORS_TABLE)
        self.create_images_table = lambda: self.executescript(CREATE_IMAGES_TABLE)
        self.create_two_view_geometries_table = lambda: self.executescript(CREATE_TWO_VIEW_GEOMETRIES_TABLE)
        self.create_keypoints_table = lambda: self.executescript(CREATE_KEYPOINTS_TABLE)
        self.create_matches_table = lambda: self.executescript(CREATE_MATCHES_TABLE)
        self.create_name_index = lambda: self.executescript(CREATE_NAME_INDEX)

    def update_camera(self, model, width, height, params, camera_id):
        params = np.asarray(params, np.float64)
        cursor = self.execute(
            "UPDATE cameras SET model=?, width=?, height=?, params=?, prior_focal_length=True WHERE camera_id=?",
            (model, width, height, params.tostring(), camera_id))
        return cursor.lastrowid

db = COLMAPDatabase.connect(root_dir / "colmap/database.db")

res = db.execute("SELECT sql FROM sqlite_master WHERE tbl_name = 'cameras' AND type = 'table'")
element = res.fetchone()[0].replace('(', '').replace(')', '')
print("\n".join([x.strip() for x in ' '.join(element.split('cameras')[1:]).strip().split(",   ")]))

res = db.execute("SELECT * FROM cameras")
all_els = res.fetchall()
df = pd.DataFrame(all_els, columns=['camera_id', 'model', 'width', 'height', 'params', 'prior_focal_length'])
df['params'] = df['params'].apply(lambda blob: np.fromstring(blob, dtype=np.float64).reshape((-1,)))
df

# %%
camera_lines = (root_dir / "colmap/sparse_custom/cameras.txt").read_text()
for line in camera_lines.strip().split("\n"):
    cameraId, cameraModel, width, height, focal, princpx, princpy = line.split(' ')
    cameraModel = camModelDict[cameraModel]
    params = np.array([focal, princpx, princpy]).astype(np.float64)
    camera_id = db.update_camera(cameraModel, int(float(width)), int(float(height)), params, int(cameraId))
db.commit()
# print(int(cameraId), cameraModel, int(float(width)), int(float(height)), params)

res = db.execute("SELECT * FROM cameras")
all_els = res.fetchall()
df = pd.DataFrame(all_els, columns=['camera_id', 'model', 'width', 'height', 'params', 'prior_focal_length'])
df['params'] = df['params'].apply(lambda blob: np.fromstring(blob, dtype=np.float64).reshape((-1,)))
df

# %%
# !colmap exhaustive_matcher --database_path $root_dir/colmap/database.db

# %%
# !colmap point_triangulator --database_path $root_dir/colmap/database.db --image_path $root_dir/colmap/images \
 --input_path $root_dir/colmap/sparse_custom --output_path $root_dir/colmap/sparse/0 --clear_points 1

# %%
# !colmap image_undistorter --image_path $root_dir/colmap/images --input_path $root_dir/colmap/sparse/0 --output_path $root_dir/colmap/dense/workspace

# %%
# !colmap patch_match_stereo --workspace_path $root_dir/colmap/dense/workspace

# %%
# !colmap stereo_fusion --workspace_path $root_dir/colmap/dense/workspace --output_path $root_dir/colmap/dense/workspace/fused.ply

# %%
# !python scripts/downsample_point.py $root_dir/colmap/dense/workspace/fused.ply $root_dir/points3D_downsample2.ply
